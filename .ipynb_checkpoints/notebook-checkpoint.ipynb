# %% [markdown]
# # mtcars
#
# In this notebook, you'll explore the iconic `mtcars` dataset. Why mtcars? Because it is a classic pedagogical dataset and there is A LOT written about it online. Every complicated concept we encounter, you should be able to google the name plus `mtcars` and find some information about it. So for example, when we study linear regression, you'll be able to google "linear regression mtcars" and find a million billion tutorials that use this dataset to teach regressions. It will give us a common vocabulary with other learners around the world.

# %% [markdown]
# ### Standard Python and R imports

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# EXAMPLE PYTHON CELL

df = pd.DataFrame(
    np.random.randint(0,100,size=(100, 2)), columns=list('AB'))
df.head()
# Out:
#     A   B
# 0  49  52
# 1  18  48
# 2  52  69
# 3  65  54
# 4  58  14

# %%
# %%R -i df
#
# # EXAMPLE R CELL
# df
# plt <- ggplot(df) +
#     geom_point(aes(A,B))
#
# plt

# %% [markdown]
# ## Load the data

# %%
# %%R
#
# # Import data with R
# mtcars <- read_csv('mtcars.csv', show_col_types = FALSE)
# mtcars %>% head(4)
# Out:
# # A tibble: 4 × 12
#   name           mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
#   <chr>        <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
# 1 Mazda RX4     21       6   160   110  3.9   2.62  16.5     0     1     4     4
# 2 Mazda RX4 W…  21       6   160   110  3.9   2.88  17.0     0     1     4     4
# 3 Datsun 710    22.8     4   108    93  3.85  2.32  18.6     1     1     4     1
# 4 Hornet 4 Dr…  21.4     6   258   110  3.08  3.22  19.4     1     0     3     1

# %%
# Import data in python
mtcars = pd.read_csv('mtcars.csv')
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# # Exploratory data analysis
#
# So far we've done a lot of looking at distributions of single variables. In this dataset we have some continuous variables (like `mpg`, `disp`, `hp`, `drat`, `wt`, and `qsec`) and some discrete variables (like `vs`, `am`, `gear`, and `carb`). Let's quickly glance through the distributions of them.

# %%
# %%R
#
# continuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')
# discrete_variables   <- c('vs', 'am', 'gear', 'carb')
#
# # Conevert to long format
# mtcars_long = mtcars %>% pivot_longer(!name, names_to = 'variable', values_to = 'value')
#
# # plot only continuous variables
# to_plot <- mtcars_long %>% filter(variable %in% continuous_variables)
#
# histogram_means <- to_plot %>%
#   group_by(variable) %>%
#   summarise(mean = mean(value))
#
# plot_continuous_histograms <- ggplot(to_plot) +
#     aes(x=value, fill=variable, group=variable) +
#     geom_histogram(bins=5) +
#     geom_vline(data=histogram_means, aes(xintercept=mean)) +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='continuous variables (means marked with a vertical line)')
#
#
# plot_continuous_dotplot <- ggplot(to_plot) +
#     aes(x=value, y=1, color=variable) +
#     geom_point(size=4, alpha=.2) +
#     stat_summary(fun.y= mean, geom="point", shape='x',
#                  size=10, color="black", alpha=1, orientation='y') +
#     facet_wrap(~variable, scales='free', ncol=1) +
#     theme_minimal() +
#     labs(
#         title = 'mtcars at a glance',
#         subtitle='continuous variables (means marked with an X)'
#     ) +
#     theme(
#             axis.text.y=element_blank(),  #remove y axis labels
#             axis.ticks.y=element_blank(),  #remove y axis ticks
#             panel.grid.major.y = element_blank(), #remove y axis grid
#             panel.grid.minor.y = element_blank(), #remove y axis grid
#     )
#
# plot_continuous
#
# # display both plots
# print(plot_continuous_histograms)
# print(plot_continuous_dotplot)

# %%
# %%R
#
# # plot only discrete variables
# to_plot <- mtcars_long %>% filter(variable %in% discrete_variables)
#
# plot_discrete <- ggplot(to_plot) +
#     aes(y=value, fill=variable) +
#     geom_bar() +
#     facet_wrap(~variable, scales='free') +
#     theme_minimal() +
#     labs(title = 'mtcars at a glance', subtitle='discrete variables')
#
#
# plot_discrete

# %% [markdown]
# 👉 What can we conclude about this dataset from the charts above?

# %% [markdown]
# # answer here
#
# disp
#
# Displacement is normally distributed in an L shape. Displacement, according to the data dictionary 'gives a good proxy for the total amount of power the engine can generate.' This chart therefore suggests that for many cars the power of the engine is on the lower end.
#
# drat
# Rear Axle Ratio is normally distributed, peaking at roughly the central point. This means that vehicles are evenly distributed in terms of torque or, for instance, towing capability.
#
# qsec
# One vehicle has significantly high performance in terms of acceleration, with the Fastest time to travel 1/4 mile from standstill

# %% [markdown]
# 👉 What can we not conclude about this dataset from the charts above?

# %% [markdown]
# # answer here
#
# hp
# Gross horsepower is normally distributed, but there is one significant vehicle with high horsepower according to this data. One engine has a notably high output. However, we cannot conclude this for sure because according to the data dictionary the output calculation was not standardised at the time of creation.

# %% [markdown]
# 👉 What further questions about this data do you have now?

# %% [markdown]
# # answer here
#
# I am generally unclear on what some of the terms mean but hope to figure it out with the help of the data dictionary

# %% [markdown]
# # Comparing variables to one another
#
# You're welcome to explore those univariate distributions more, but let's focus on something new. Comparing variables to one another. I'll start you off with a basic scatter plot.

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=wt) +
#     geom_point()

# %% [markdown]
# # 👉 Try It
#
# 1. Imporve the chart above. Add a title and subtitle, and better axis labels. Be **very careful** about the language you use in the headline. Assume you have a very strict copyeditor, make the language easy to understand but make sure you're not saying more than what the data proves.
#
# 2. Answer the questions below:
#
#     a. What can we conclude about fuel efficiency and weight <br />
#     The lower the weight of a vehicle, the higher the fuel efficiency. The heavier the vehicle the lower the fuel efficiency <br />
#
#     b. What can't we conclude about fuel efficiency and weight <br />
#     We can't conclude that weight is the only contributor for fuel efficiency <br />
#
#     c. What further questions do you have about this data? <br />
#     What else affects fuel efficiency?

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=wt, color=qsec) +
#     geom_point()+
#     geom_smooth(method=lm) +
#     labs(
#         title='The lower the weight of a vehicle, the higher the fuel efficiency',
#         subtitle="The heavier the vehicle the lower the fuel efficiency",
#         y="Fuel efficiency in miles per gallon",
#         x="weight"
#         )
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ## Part 1 (Gudied Inquiry)
# # 👉 What makes cars more fuel efficient?
# The higher the torque the higher the fuel efficiency <br/>
# The lower the number of cylinder engines the higher the fuel efficiency <br/>
# The lower the number of caburators the higher the fuel efficiency

# %%
# %%R
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=mpg, x=drat) +
#     geom_point()
#
# plot_scatterplots

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=cyl) +
#     geom_point()

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=gear) +
#     geom_point()

# %%
# %%R
#
# ggplot(mtcars) +
#     aes(y=mpg, x=carb) +
#     geom_point()

# %% [markdown]
# ## Part 2 (freeform inquiry)
# Ask and try to answer your own questions about the dataset. Make at least two such charts below:

# %% [markdown]
# # 👉 Question 1: TKTK
#
# What affects a car's ability to hit 1/4 mile

# %% [markdown]
# ### 👉 Charts or summary statistics to help answer your question

# %%
# %%R
#
# # ggplot code here
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=qsec, x=wt) +
#     geom_point()
#
# plot_scatterplots

# %%
# %%R
#
# # ggplot code here
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=qsec, x=mpg) +
#     geom_point()
#
# plot_scatterplots

# %%
# %%R
#
# # ggplot code here
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=qsec, x=drat) +
#     geom_point()
#
# plot_scatterplots

# %%
# %%R
#
# # ggplot code here
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=qsec, x=disp) +
#     geom_point()
#
# plot_scatterplots

# %%
# %%R
#
# # ggplot code here
#
# plot_scatterplots<-ggplot(mtcars) +
#     aes(y=qsec, x=hp) +
#     geom_point()
#
# plot_scatterplots

# %% [markdown]
# ### 👉 Reflection
#
# a. What can we conclude?
# It is possible that the more the horsepower the more slowly a car gets to a quarter mile. However, there is a disclaimer in the data dictionary about the reliability of the horsepower data.
#
# b. What can't we conclude?
# If there is a correlation between weight and qsec, it is unclear
# There seems to be a small but still inconclusive correlation between qsec and mpg. That is, more fuel efficient cars can have reach a quarter mile fast but it is not true throughout the board
#
# c. What further questions does this analysis raise?
# Is there a way to create a mathematical formula that would predict qsec

# %% [markdown]
# #Attempt at function

# %%
# %%R
#
# continuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')
# discrete_variables   <- c('vs', 'am', 'gear', 'carb')
#
#
# scatter_variables<-function(continuous_variables){
#     ggplot(mtcars) +
#     aes(y=mpg, x=value) +
#     geom_point()
# }
#
# print(scatter_variables(continuous_variables))
#
# # for(continuous_variable in continuous_variables) {
# #    print(scatter_variables(continuous_variable))
# # }
# Out:
# Error in `geom_point()`:
# ! Problem while computing aesthetics.
# ℹ Error occurred in the 1st layer.
# Caused by error in `FUN()`:
# ! object 'value' not found
# Run `rlang::last_error()` to see where the error occurred.
#
# Error in geom_point() :
# ℹ Error occurred in the 1st layer.
# Caused by error in `FUN()`:
# ! object 'value' not found
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:331, in RMagics.eval(self, code)
#     329 try:
#     330     # Need the newline in case the last line in code is a comment.
# --> 331     value, visible = ro.r("withVisible({%s\n})" % code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:204, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     203         kwargs[r_k] = v
# --> 204 return (super(SignatureTranslatedFunction, self)
#     205         .__call__(*args, **kwargs))
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/robjects/functions.py:127, in Function.__call__(self, *args, **kwargs)
#     126         new_kwargs[k] = cv.py2rpy(v)
# --> 127 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     128 res = cv.rpy2py(res)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/rinterface.py:815, in SexpClosure.__call__(self, *args, **kwargs)
#     814     if error_occured[0]:
# --> 815         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     816 return res
#
# RRuntimeError: Error in geom_point() :
# ℹ Error occurred in the 1st layer.
# Caused by error in `FUN()`:
# ! object 'value' not found
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In [87], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', "\ncontinuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')\ndiscrete_variables   <- c('vs', 'am', 'gear', 'carb')\n\n\nscatter_variables<-function(continuous_variables){\n    ggplot(mtcars) +\n    aes(y=mpg, x=value) +\n    geom_point()\n} \n\nprint(scatter_variables(continuous_variables))\n\n# for(continuous_variable in continuous_variables) {\n#    print(scatter_variables(continuous_variable))\n# }\n")
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2415 with self.builtin_trap:
#    2416     args = (magic_arg_s, cell)
# -> 2417     result = fn(*args, **kwargs)
#    2418 return result
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:868, in RMagics.R(self, line, cell, local_ns)
#     866     if not e.stdout.endswith(e.err):
#     867         print(e.err)
# --> 868     raise e
#     869 finally:
#     870     if self.device in ['png', 'svg']:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:848, in RMagics.R(self, line, cell, local_ns)
#     846         return_output = False
#     847 else:
# --> 848     text_result, result, visible = self.eval(code)
#     849     text_output += text_result
#     850     if visible:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:335, in RMagics.eval(self, code)
#     332 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     333     # Otherwise next return seems to have copy of error.
#     334     warning_or_other_msg = self.flush()
# --> 335     raise RInterpreterError(code, str(exception),
#     336                             warning_or_other_msg)
#     337 text_output = self.flush()
#     338 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line "\ncontinuous_variables <- c('mpg', 'disp', 'hp', 'drat', 'wt', 'qsec')\ndiscrete_variables   <- c('vs', 'am', 'gear', 'carb')\n\n\nscatter_variables<-function(continuous_variables){\n    ggplot(mtcars) +\n    aes(y=mpg, x=value) +\n    geom_point()\n} \n\nprint(scatter_variables(continuous_variables))\n\n# for(continuous_variable in continuous_variables) {\n#    print(scatter_variables(continuous_variable))\n# }\n".
# R error message: "Error in geom_point() : \nℹ Error occurred in the 1st layer.\nCaused by error in `FUN()`:\n! object 'value' not found"
